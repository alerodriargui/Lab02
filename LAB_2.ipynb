# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1TFC0coLdLbK9Lf3_Ia2FDgw9AoqGf3bT" width=180, align="center"/>
#
# Master's degree in Intelligent Systems
#
# Subject: 11754 - Deep Learning
#
# Year: 2025-2026
#
# Professor: Miguel Ángel Calafat Torrens

# %% [markdown]
# # LAB 2
#
# In this lab you have to deliver one single file that will be built by yourself using `LESSON_2B.ipynb` as a template.
#
# You have to deliver your version of `LESSON_2B.ipynb` with all the cells executed and showing the results of the execution.
#
# The additional requirements that you have to accomplish are the following:
#
# * You will use the same dataset (the same images). But in this case you have to leave them all in the same folder, without using any subfolder for the different classes.
#
# * You have to create and use a custom dataset class. This custom dataset class must have `torch.utils.data.Dataset` as parent class, and must have at least the following properties:
# ```
#         self.image_paths  # List of paths as strings
#         self.transform    # Transformations
#         self.classes      # Unique labels as strings
#         self.class_to_idx # Dictionary mapping classes to indexes. For example: {'cloudy':0, `rain`:1, ...}
#         self.labels       # List of integers with labels corresponding to the list of paths (image_paths)
# ```
#
# * The signature of the init function of this custom dataset class should be: `def __init__(self, im_paths, transform=None):` where `im_paths` is a list of strings with the paths to images. The labels has to be created automatically using the names of the image files without the numbers.
#
# * The shape (height and width) of the images, once transformed, should be (240, 240).
#
# * You define your CNN class as a custom model with **at least 4 convolutional blocks.**
#
# * Train it so that it gets a test accuracy of **at least 90%.**
#
# * Do the part of transfer learning with a different model. Don't use VGG; use any other of those available.
#
# * **Explain the results**. Insert a cell at the end with these explanations. Compare the results of the custom CNN and the one with transfer learning. Explain the plots and highlight the differences between them. Make any additional considerations you feel are appropriate about depth of the networks, dropout rates, or anything that shows you understand what you've done.
#
# **You don't have to deliver this file. You only should deliver your version of `LESSON_2B.ipynb`.**

# %% [markdown]
# ## Additional Exercises
#
# Answer the following questions in separate markdown cells at the end of your delivered notebook:
#
# 1. **Loss functions:** Explain the relationship between `NLLLoss` + `LogSoftmax` and `CrossEntropyLoss`. Why can they be used interchangeably? When would you choose one over the other?
#
# 2. **Dropout analysis:** Look at your training and validation loss curves. What differences do you observe with and without dropout? If validation loss is consistently below training loss, what does that indicate?
#
# 3. **Transfer learning trade-offs:** Your transfer learning model had most layers frozen. What are the advantages and disadvantages of this approach? In what scenario would you unfreeze some layers (fine-tuning)?
#
# 4. **Learning rate impact:** After training your custom CNN, resume training from a checkpoint with a learning rate 10x smaller than your original. Show the loss curves before and after the change. What do you observe? (This requires loading a checkpoint and training for a few more epochs.)
